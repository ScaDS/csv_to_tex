# %% [markdown]
# <html>
#             <div style="font-size:7pt">
#             This notebook may contain text, code and images generated by artificial intelligence.
#             Used model: gpt-4o-2024-05-13,
#             vision model: gpt-4o-2024-05-13,
#             endpoint: None,
#             bia-bob version: 0.18.0.
#             It is good scientific practice to check the code and results it produces carefully.
#             <a href="https://github.com/haesleinhuepf/bia-bob">Read more about code generation using bia-bob</a>.
#             </div>
#             </html>

# %% [markdown]
# # Curate and Convert Trainings
#
# This notebook processes a CSV file containing trainings data. The steps include loading the data, cleaning it, filtering it, and finally converting it to a LaTeX formatted string for document preparation.

# %%
import pandas as pd
import numpy as np
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
filename = 'trainings-example.csv'

# %% [markdown]
# ## Load the CSV file into a dataframe

# %%
df = pd.read_csv(filename, header=1)

df.head(10)
# Out:
#    Unnamed: 0             Start/Ende  \
# 0         NaN                laufend
# 1         NaN               11/23/23
# 2         NaN                8/28/23
# 3         NaN  09.10.2023-02.02.2024
# 4         NaN                laufend
# 5         NaN                5/24/23
# 6         NaN                 6/1/23
# 7         NaN                10/1/24
# 8         NaN                    NaN
# 9         NaN                4/27/24
#
#                                          Titel    #TN      Verantwortl.  Uni  \
# 0                                 Datenanalyse    NaN   Matthias Peters   UL
# 1                                      Imaging   15.0     Maria Schmidt   UL
# 2               Image Analysis Training School   25.0      Robert Lange  TUD
# 3                             Studienpraktikum    1.0     Nikolaus Rode   UL
# 4          Trainings zu Datenanalyse und KI/ML    7.0  Thomas Bergweich   UL
# 5                  Training Data Visualization   10.0          Jan Baum   UL
# 6  Training Data Visualization @ DataWeek 2023   20.0          Jan Baum   UL
# 7            Tag der offenen Tür (ML Training)  100.0     Johannes Haus   UL
# 8                                          NaN    NaN               NaN  NaN
# 9      “Cultivating Training”, Online Webinar    60.0       Robert Hund   UL
#
#                   link  Unnamed: 7
# 0                  NaN         NaN
# 1                  NaN         NaN
# 2                  NaN         NaN
# 3                  NaN         NaN
# 4                  NaN         NaN
# 5                  NaN         NaN
# 6                  NaN         NaN
# 7                  NaN         NaN
# 8                  NaN         NaN
# 9  https://github.com/         NaN

# %% [markdown]
# ## Standardize column names

# %%
# Rename the column
df.rename(columns={"#TN": "Num_students"}, inplace=True)
df.rename(columns={"Verantwortl.": "Betreuer_aus_scadsai"}, inplace=True)

# Verify the column renaming
df.head()
# Out:
#    Unnamed: 0             Start/Ende                                Titel  \
# 0         NaN                laufend                         Datenanalyse
# 1         NaN               11/23/23                              Imaging
# 2         NaN                8/28/23       Image Analysis Training School
# 3         NaN  09.10.2023-02.02.2024                     Studienpraktikum
# 4         NaN                laufend  Trainings zu Datenanalyse und KI/ML
#
#    Num_students Betreuer_aus_scadsai  Uni link  Unnamed: 7
# 0           NaN      Matthias Peters   UL  NaN         NaN
# 1          15.0        Maria Schmidt   UL  NaN         NaN
# 2          25.0         Robert Lange  TUD  NaN         NaN
# 3           1.0        Nikolaus Rode   UL  NaN         NaN
# 4           7.0     Thomas Bergweich   UL  NaN         NaN

# %% [markdown]
# ## Cleaning the Start/End column

# %%
def keep_first_date(date_str):
    return str(date_str).split('-')[0].strip() if '-' in str(date_str) else date_str

# Apply the custom function to the column
df["Start/Ende"] = df["Start/Ende"].apply(keep_first_date)

# Replace "laufend" with NaN
df["Start/Ende"].replace("laufend", np.nan, inplace=True)

# Make sure the year is in the column
df["Start/Ende"] = df["Start/Ende"].str.replace("/23", "/2023")
df["Start/Ende"] = df["Start/Ende"].str.replace("/2023/", "/23/")

# Verify the changes
df.head()
# Out:
# /var/folders/p1/6svzckgd1y5906pfgm71fvmr0000gn/T/ipykernel_65327/3130607592.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Start/Ende"].replace("laufend", np.nan, inplace=True)
#    Unnamed: 0  Start/Ende                                Titel  Num_students  \
# 0         NaN         NaN                         Datenanalyse           NaN
# 1         NaN  11/23/2023                              Imaging          15.0
# 2         NaN   8/28/2023       Image Analysis Training School          25.0
# 3         NaN  09.10.2023                     Studienpraktikum           1.0
# 4         NaN         NaN  Trainings zu Datenanalyse und KI/ML           7.0
#
#   Betreuer_aus_scadsai  Uni link  Unnamed: 7
# 0      Matthias Peters   UL  NaN         NaN
# 1        Maria Schmidt   UL  NaN         NaN
# 2         Robert Lange  TUD  NaN         NaN
# 3        Nikolaus Rode   UL  NaN         NaN
# 4     Thomas Bergweich   UL  NaN         NaN

# %% [markdown]
# ## Replace non-numeric strings in `Num_students` with zero

# %%
df['Num_students'] = pd.to_numeric(df['Num_students'], errors='coerce').fillna(0)

df.head(10)
# Out:
#    Unnamed: 0  Start/Ende                                        Titel  \
# 0         NaN         NaN                                 Datenanalyse
# 1         NaN  11/23/2023                                      Imaging
# 2         NaN   8/28/2023               Image Analysis Training School
# 3         NaN  09.10.2023                             Studienpraktikum
# 4         NaN         NaN          Trainings zu Datenanalyse und KI/ML
# 5         NaN   5/24/2023                  Training Data Visualization
# 6         NaN    6/1/2023  Training Data Visualization @ DataWeek 2023
# 7         NaN     10/1/24            Tag der offenen Tür (ML Training)
# 8         NaN         NaN                                          NaN
# 9         NaN     4/27/24      “Cultivating Training”, Online Webinar
#
#    Num_students Betreuer_aus_scadsai  Uni                 link  Unnamed: 7
# 0           0.0      Matthias Peters   UL                  NaN         NaN
# 1          15.0        Maria Schmidt   UL                  NaN         NaN
# 2          25.0         Robert Lange  TUD                  NaN         NaN
# 3           1.0        Nikolaus Rode   UL                  NaN         NaN
# 4           7.0     Thomas Bergweich   UL                  NaN         NaN
# 5          10.0             Jan Baum   UL                  NaN         NaN
# 6          20.0             Jan Baum   UL                  NaN         NaN
# 7         100.0        Johannes Haus   UL                  NaN         NaN
# 8           0.0                  NaN  NaN                  NaN         NaN
# 9          60.0          Robert Hund   UL  https://github.com/         NaN

# %% [markdown]
# ## Convert `Num_students` to integers

# %%
df['Num_students'] = df['Num_students'].astype(int)

df.head(10)
# Out:
#    Unnamed: 0  Start/Ende                                        Titel  \
# 0         NaN         NaN                                 Datenanalyse
# 1         NaN  11/23/2023                                      Imaging
# 2         NaN   8/28/2023               Image Analysis Training School
# 3         NaN  09.10.2023                             Studienpraktikum
# 4         NaN         NaN          Trainings zu Datenanalyse und KI/ML
# 5         NaN   5/24/2023                  Training Data Visualization
# 6         NaN    6/1/2023  Training Data Visualization @ DataWeek 2023
# 7         NaN     10/1/24            Tag der offenen Tür (ML Training)
# 8         NaN         NaN                                          NaN
# 9         NaN     4/27/24      “Cultivating Training”, Online Webinar
#
#    Num_students Betreuer_aus_scadsai  Uni                 link  Unnamed: 7
# 0             0      Matthias Peters   UL                  NaN         NaN
# 1            15        Maria Schmidt   UL                  NaN         NaN
# 2            25         Robert Lange  TUD                  NaN         NaN
# 3             1        Nikolaus Rode   UL                  NaN         NaN
# 4             7     Thomas Bergweich   UL                  NaN         NaN
# 5            10             Jan Baum   UL                  NaN         NaN
# 6            20             Jan Baum   UL                  NaN         NaN
# 7           100        Johannes Haus   UL                  NaN         NaN
# 8             0                  NaN  NaN                  NaN         NaN
# 9            60          Robert Hund   UL  https://github.com/         NaN

# %% [markdown]
# ## Select specific columns

# %%
df = df[["Start/Ende", "Titel", "Num_students", "Betreuer_aus_scadsai", "Uni"]]
df.head(10)
# Out:
#    Start/Ende                                        Titel  Num_students  \
# 0         NaN                                 Datenanalyse             0
# 1  11/23/2023                                      Imaging            15
# 2   8/28/2023               Image Analysis Training School            25
# 3  09.10.2023                             Studienpraktikum             1
# 4         NaN          Trainings zu Datenanalyse und KI/ML             7
# 5   5/24/2023                  Training Data Visualization            10
# 6    6/1/2023  Training Data Visualization @ DataWeek 2023            20
# 7     10/1/24            Tag der offenen Tür (ML Training)           100
# 8         NaN                                          NaN             0
# 9     4/27/24      “Cultivating Training”, Online Webinar             60
#
#   Betreuer_aus_scadsai  Uni
# 0      Matthias Peters   UL
# 1        Maria Schmidt   UL
# 2         Robert Lange  TUD
# 3        Nikolaus Rode   UL
# 4     Thomas Bergweich   UL
# 5             Jan Baum   UL
# 6             Jan Baum   UL
# 7        Johannes Haus   UL
# 8                  NaN  NaN
# 9          Robert Hund   UL

# %% [markdown]
# ## Filter out empty lines

# %%
df = df.dropna(how='all')
df.head(10)
# Out:
#    Start/Ende                                        Titel  Num_students  \
# 0         NaN                                 Datenanalyse             0
# 1  11/23/2023                                      Imaging            15
# 2   8/28/2023               Image Analysis Training School            25
# 3  09.10.2023                             Studienpraktikum             1
# 4         NaN          Trainings zu Datenanalyse und KI/ML             7
# 5   5/24/2023                  Training Data Visualization            10
# 6    6/1/2023  Training Data Visualization @ DataWeek 2023            20
# 7     10/1/24            Tag der offenen Tür (ML Training)           100
# 8         NaN                                          NaN             0
# 9     4/27/24      “Cultivating Training”, Online Webinar             60
#
#   Betreuer_aus_scadsai  Uni
# 0      Matthias Peters   UL
# 1        Maria Schmidt   UL
# 2         Robert Lange  TUD
# 3        Nikolaus Rode   UL
# 4     Thomas Bergweich   UL
# 5             Jan Baum   UL
# 6             Jan Baum   UL
# 7        Johannes Haus   UL
# 8                  NaN  NaN
# 9          Robert Hund   UL

# %% [markdown]
# ## Filter rows containing '2023' in the 'Semester' column

# %%
df = df[df['Start/Ende'].str.contains("2023", na=False)]
df.head(10)
# Out:
#    Start/Ende                                        Titel  Num_students  \
# 1  11/23/2023                                      Imaging            15
# 2   8/28/2023               Image Analysis Training School            25
# 3  09.10.2023                             Studienpraktikum             1
# 5   5/24/2023                  Training Data Visualization            10
# 6    6/1/2023  Training Data Visualization @ DataWeek 2023            20
#
#   Betreuer_aus_scadsai  Uni
# 1        Maria Schmidt   UL
# 2         Robert Lange  TUD
# 3        Nikolaus Rode   UL
# 5             Jan Baum   UL
# 6             Jan Baum   UL

# %% [markdown]
# ## Filter out trainings with attendees < 4

# %%
df = df[df['Num_students'] >= 4]
df.head(10)
# Out:
#    Start/Ende                                        Titel  Num_students  \
# 1  11/23/2023                                      Imaging            15
# 2   8/28/2023               Image Analysis Training School            25
# 5   5/24/2023                  Training Data Visualization            10
# 6    6/1/2023  Training Data Visualization @ DataWeek 2023            20
#
#   Betreuer_aus_scadsai  Uni
# 1        Maria Schmidt   UL
# 2         Robert Lange  TUD
# 5             Jan Baum   UL
# 6             Jan Baum   UL

# %% [markdown]
# ## Rename columns for print

# %%
df.rename(columns={
    "Start/Ende": "Datum",
    "Betreuer_aus_scadsai": "Verantw.",
    "Num_students": "# Stud."
}, inplace=True)
df.head(10)
# Out:
#         Datum                                        Titel  # Stud.  \
# 1  11/23/2023                                      Imaging       15
# 2   8/28/2023               Image Analysis Training School       25
# 5   5/24/2023                  Training Data Visualization       10
# 6    6/1/2023  Training Data Visualization @ DataWeek 2023       20
#
#         Verantw.  Uni
# 1  Maria Schmidt   UL
# 2   Robert Lange  TUD
# 5       Jan Baum   UL
# 6       Jan Baum   UL

# %% [markdown]
# ## Convert the dataframe to a LaTeX formatted string and save to a .tex file

# %%
latex_string = df.to_latex(index=False)

latex_string = latex_string.replace("\\begin{tabular}{llrll}", "\\begin{longtable}{|p{.12\\textwidth}|p{.38\\textwidth}|p{.04\\textwidth}|p{.2\\textwidth}|p{.08\\textwidth}|}")
latex_string = latex_string.replace("\\end{tabular}", "\\end{longtable}")
latex_string = latex_string.replace("\\toprule", "\\hline")
latex_string = latex_string.replace("\\midrule", "\\hline")
latex_string = latex_string.replace("\\bottomrule", "\\hline")
latex_string = latex_string.replace("\\\\", "\\\\ \\hline")

with open(filename.replace(".csv", ".tex"), 'w') as f:
    f.write(latex_string)

# %% [markdown]
# ## Print the LaTeX formatted string

# %%
print(latex_string)
# Out:
# \begin{longtable}{|p{.12\textwidth}|p{.38\textwidth}|p{.04\textwidth}|p{.2\textwidth}|p{.08\textwidth}|}
# \hline
# Datum & Titel & # Stud. & Verantw. & Uni \\ \hline
# \hline
# 11/23/2023 & Imaging & 15 & Maria Schmidt & UL \\ \hline
# 8/28/2023 & Image Analysis Training School & 25 & Robert Lange & TUD \\ \hline
# 5/24/2023 & Training Data Visualization & 10 & Jan Baum & UL \\ \hline
# 6/1/2023 & Training Data Visualization @ DataWeek 2023 & 20 & Jan Baum & UL \\ \hline
# \hline
# \end{longtable}
